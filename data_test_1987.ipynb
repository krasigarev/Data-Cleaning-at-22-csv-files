# %%
import pandas as pd

# %%
df = pd.read_csv('dataverse_files/1987.csv.bz2', engine='pyarrow')
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        1987     10          14          3    741.0         730    912.0
# 1        1987     10          15          4    729.0         730    903.0
# 2        1987     10          17          6    741.0         730    918.0
# 3        1987     10          18          7    729.0         730    847.0
# 4        1987     10          19          1    749.0         730    922.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1311821  1987     12          11          5   1530.0        1530   1825.0
# 1311822  1987     12          13          7   1530.0        1530   1815.0
# 1311823  1987     12          14          1   1530.0        1530   1807.0
# 1311824  1987     12           1          2   1525.0        1525   1643.0
# 1311825  1987     12           2          3   1540.0        1525   1706.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 0               849            PS       1451  ...     NaN      NaN          0
# 1               849            PS       1451  ...     NaN      NaN          0
# 2               849            PS       1451  ...     NaN      NaN          0
# 3               849            PS       1451  ...     NaN      NaN          0
# 4               849            PS       1451  ...     NaN      NaN          0
# ...             ...           ...        ...  ...     ...      ...        ...
# 1311821        1823            CO        638  ...     NaN      NaN          0
# 1311822        1823            CO        638  ...     NaN      NaN          0
# 1311823        1823            CO        638  ...     NaN      NaN          0
# 1311824        1638            CO        639  ...     NaN      NaN          0
# 1311825        1638            CO        639  ...     NaN      NaN          0
#
#          CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                     NaN         0           NaN          NaN      NaN
# 1                     NaN         0           NaN          NaN      NaN
# 2                     NaN         0           NaN          NaN      NaN
# 3                     NaN         0           NaN          NaN      NaN
# 4                     NaN         0           NaN          NaN      NaN
# ...                   ...       ...           ...          ...      ...
# 1311821               NaN         0           NaN          NaN      NaN
# 1311822               NaN         0           NaN          NaN      NaN
# 1311823               NaN         0           NaN          NaN      NaN
# 1311824               NaN         0           NaN          NaN      NaN
# 1311825               NaN         0           NaN          NaN      NaN
#
#          SecurityDelay  LateAircraftDelay
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ...                ...                ...
# 1311821            NaN                NaN
# 1311822            NaN                NaN
# 1311823            NaN                NaN
# 1311824            NaN                NaN
# 1311825            NaN                NaN
#
# [1311826 rows x 29 columns]

# %%
def df_info(df):
    summary = pd.DataFrame(df.info())
    shape = df.shape
    size = df.size
    return summary, shape, size

df_info(df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1311826 entries, 0 to 1311825
# Data columns (total 29 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Year               1311826 non-null  int64
#  1   Month              1311826 non-null  int64
#  2   DayofMonth         1311826 non-null  int64
#  3   DayOfWeek          1311826 non-null  int64
#  4   DepTime            1292141 non-null  float64
#  5   CRSDepTime         1311826 non-null  int64
#  6   ArrTime            1288326 non-null  float64
#  7   CRSArrTime         1311826 non-null  int64
#  8   UniqueCarrier      1311826 non-null  str
#  9   FlightNum          1311826 non-null  int64
#  10  TailNum            0 non-null        float64
#  11  ActualElapsedTime  1288326 non-null  float64
#  12  CRSElapsedTime     1311826 non-null  int64
#  13  AirTime            0 non-null        float64
#  14  ArrDelay           1288326 non-null  float64
#  15  DepDelay           1292141 non-null  float64
#  16  Origin             1311826 non-null  str
#  17  Dest               1311826 non-null  str
#  18  Distance           1310811 non-null  float64
#  19  TaxiIn             0 non-null        float64
#  20  TaxiOut            0 non-null        float64
#  21  Cancelled          1311826 non-null  int64
#  22  CancellationCode   0 non-null        float64
#  23  Diverted           1311826 non-null  int64
#  24  CarrierDelay       0 non-null        float64
#  25  WeatherDelay       0 non-null        float64
#  26  NASDelay           0 non-null        float64
#  27  SecurityDelay      0 non-null        float64
#  28  LateAircraftDelay  0 non-null        float64
# dtypes: float64(16), int64(10), str(3)
# memory usage: 300.3 MB
# (Empty DataFrame
#  Columns: []
#  Index: [],
#  (1311826, 29),
#  38042954)

# %%
def adult(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'nulls': df.isnull().sum(),
        'nulls_%': (df.isnull().mean() * 100).round(2),
        'nunique': df.nunique(),
        'sample': df.iloc[0]
    })
    return summary

# %%
adult(df)
# Out:
#                      dtype    nulls  nulls_%  nunique sample
# Year                 int64        0     0.00        1   1987
# Month                int64        0     0.00        3     10
# DayofMonth           int64        0     0.00       31     14
# DayOfWeek            int64        0     0.00        7      3
# DepTime            float64    19685     1.50     1430  741.0
# CRSDepTime           int64        0     0.00     1174    730
# ArrTime            float64    23500     1.79     1440  912.0
# CRSArrTime           int64        0     0.00     1301    849
# UniqueCarrier          str        0     0.00       14     PS
# FlightNum            int64        0     0.00     2161   1451
# TailNum            float64  1311826   100.00        0    NaN
# ActualElapsedTime  float64    23500     1.79      647   91.0
# CRSElapsedTime       int64        0     0.00      431     79
# AirTime            float64  1311826   100.00        0    NaN
# ArrDelay           float64    23500     1.79      672   23.0
# DepDelay           float64    19685     1.50      605   11.0
# Origin                 str        0     0.00      237    SAN
# Dest                   str        0     0.00      237    SFO
# Distance           float64     1015     0.08     1026  447.0
# TaxiIn             float64  1311826   100.00        0    NaN
# TaxiOut            float64  1311826   100.00        0    NaN
# Cancelled            int64        0     0.00        2      0
# CancellationCode   float64  1311826   100.00        0    NaN
# Diverted             int64        0     0.00        2      0
# CarrierDelay       float64  1311826   100.00        0    NaN
# WeatherDelay       float64  1311826   100.00        0    NaN
# NASDelay           float64  1311826   100.00        0    NaN
# SecurityDelay      float64  1311826   100.00        0    NaN
# LateAircraftDelay  float64  1311826   100.00        0    NaN

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# DepTime                19685
# CRSDepTime                 0
# ArrTime                23500
# CRSArrTime                 0
# UniqueCarrier              0
# FlightNum                  0
# TailNum              1311826
# ActualElapsedTime      23500
# CRSElapsedTime             0
# AirTime              1311826
# ArrDelay               23500
# DepDelay               19685
# Origin                     0
# Dest                       0
# Distance                1015
# TaxiIn               1311826
# TaxiOut              1311826
# Cancelled                  0
# CancellationCode     1311826
# Diverted                   0
# CarrierDelay         1311826
# WeatherDelay         1311826
# NASDelay             1311826
# SecurityDelay        1311826
# LateAircraftDelay    1311826
# dtype: int64

# %%
(df.isnull().mean() * 100).round(2).sort_values(ascending=False)
# Out:
# TailNum              100.00
# SecurityDelay        100.00
# TaxiIn               100.00
# TaxiOut              100.00
# LateAircraftDelay    100.00
# CancellationCode     100.00
# CarrierDelay         100.00
# NASDelay             100.00
# WeatherDelay         100.00
# AirTime              100.00
# ArrTime                1.79
# ArrDelay               1.79
# ActualElapsedTime      1.79
# DepDelay               1.50
# DepTime                1.50
# Distance               0.08
# CRSElapsedTime         0.00
# CRSDepTime             0.00
# Month                  0.00
# DayofMonth             0.00
# DayOfWeek              0.00
# Year                   0.00
# FlightNum              0.00
# CRSArrTime             0.00
# UniqueCarrier          0.00
# Dest                   0.00
# Origin                 0.00
# Diverted               0.00
# Cancelled              0.00
# dtype: float64

# %%
df[df['DepTime'].isnull()]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 52       1987     10          12          1      NaN        1505      NaN
# 79       1987     10          12          1      NaN        1635      NaN
# 98       1987     10           6          2      NaN         830      NaN
# 161      1987     10          29          4      NaN         930      NaN
# 263      1987     10          22          4      NaN        2000      NaN
# ...       ...    ...         ...        ...      ...         ...      ...
# 1311677  1987     12           2          3      NaN        1430      NaN
# 1311687  1987     12          15          2      NaN        1455      NaN
# 1311698  1987     12          28          1      NaN        1455      NaN
# 1311783  1987     12          28          1      NaN        1510      NaN
# 1311800  1987     12          15          2      NaN        1615      NaN
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# 52             1608            PS       1453  ...     NaN      NaN          1
# 79             1732            PS       1454  ...     NaN      NaN          1
# 98              937            PS       1457  ...     NaN      NaN          1
# 161            1040            PS       1459  ...     NaN      NaN          1
# 263            2059            PS       1465  ...     NaN      NaN          1
# ...             ...           ...        ...  ...     ...      ...        ...
# 1311677        1545            CO        633  ...     NaN      NaN          1
# 1311687        1614            CO        633  ...     NaN      NaN          1
# 1311698        1614            CO        633  ...     NaN      NaN          1
# 1311783        1810            CO        636  ...     NaN      NaN          1
# 1311800        1733            CO        637  ...     NaN      NaN          1
#
#          CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 52                    NaN         0           NaN          NaN      NaN
# 79                    NaN         0           NaN          NaN      NaN
# 98                    NaN         0           NaN          NaN      NaN
# 161                   NaN         0           NaN          NaN      NaN
# 263                   NaN         0           NaN          NaN      NaN
# ...                   ...       ...           ...          ...      ...
# 1311677               NaN         0           NaN          NaN      NaN
# 1311687               NaN         0           NaN          NaN      NaN
# 1311698               NaN         0           NaN          NaN      NaN
# 1311783               NaN         0           NaN          NaN      NaN
# 1311800               NaN         0           NaN          NaN      NaN
#
#          SecurityDelay  LateAircraftDelay
# 52                 NaN                NaN
# 79                 NaN                NaN
# 98                 NaN                NaN
# 161                NaN                NaN
# 263                NaN                NaN
# ...                ...                ...
# 1311677            NaN                NaN
# 1311687            NaN                NaN
# 1311698            NaN                NaN
# 1311783            NaN                NaN
# 1311800            NaN                NaN
#
# [19685 rows x 29 columns]

# %%
adult(df)
# Out:
#                      dtype    nulls  nulls_%  nunique sample
# Year                 int64        0     0.00        1   1987
# Month                int64        0     0.00        3     10
# DayofMonth           int64        0     0.00       31     14
# DayOfWeek            int64        0     0.00        7      3
# DepTime            float64    19685     1.50     1430  741.0
# CRSDepTime           int64        0     0.00     1174    730
# ArrTime            float64    23500     1.79     1440  912.0
# CRSArrTime           int64        0     0.00     1301    849
# UniqueCarrier          str        0     0.00       14     PS
# FlightNum            int64        0     0.00     2161   1451
# TailNum            float64  1311826   100.00        0    NaN
# ActualElapsedTime  float64    23500     1.79      647   91.0
# CRSElapsedTime       int64        0     0.00      431     79
# AirTime            float64  1311826   100.00        0    NaN
# ArrDelay           float64    23500     1.79      672   23.0
# DepDelay           float64    19685     1.50      605   11.0
# Origin                 str        0     0.00      237    SAN
# Dest                   str        0     0.00      237    SFO
# Distance           float64     1015     0.08     1026  447.0
# TaxiIn             float64  1311826   100.00        0    NaN
# TaxiOut            float64  1311826   100.00        0    NaN
# Cancelled            int64        0     0.00        2      0
# CancellationCode   float64  1311826   100.00        0    NaN
# Diverted             int64        0     0.00        2      0
# CarrierDelay       float64  1311826   100.00        0    NaN
# WeatherDelay       float64  1311826   100.00        0    NaN
# NASDelay           float64  1311826   100.00        0    NaN
# SecurityDelay      float64  1311826   100.00        0    NaN
# LateAircraftDelay  float64  1311826   100.00        0    NaN

# %%
col = ['TailNum', 'AirTime', 'TaxiIn', 'TaxiOut', 'CancellationCode', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']

# %%
df.drop(columns=col, inplace=True)

# %%
adult(df)
# Out:
#                      dtype  nulls  nulls_%  nunique sample
# Year                 int64      0     0.00        1   1987
# Month                int64      0     0.00        3     10
# DayofMonth           int64      0     0.00       31     14
# DayOfWeek            int64      0     0.00        7      3
# DepTime            float64  19685     1.50     1430  741.0
# CRSDepTime           int64      0     0.00     1174    730
# ArrTime            float64  23500     1.79     1440  912.0
# CRSArrTime           int64      0     0.00     1301    849
# UniqueCarrier          str      0     0.00       14     PS
# FlightNum            int64      0     0.00     2161   1451
# ActualElapsedTime  float64  23500     1.79      647   91.0
# CRSElapsedTime       int64      0     0.00      431     79
# ArrDelay           float64  23500     1.79      672   23.0
# DepDelay           float64  19685     1.50      605   11.0
# Origin                 str      0     0.00      237    SAN
# Dest                   str      0     0.00      237    SFO
# Distance           float64   1015     0.08     1026  447.0
# Cancelled            int64      0     0.00        2      0
# Diverted             int64      0     0.00        2      0

# %%
df['DepTime'] = df['DepTime'].fillna(df.DepTime.mean())

# %%
df['ArrTime'] = df['ArrTime'].fillna(df.ArrTime.mean())
df['ActualElapsedTime'] = df['ActualElapsedTime'].fillna(df.ActualElapsedTime.mean())
df['ArrDelay'] = df['ArrDelay'].fillna(df.ArrDelay.mean())
df['DepDelay'] = df['DepDelay'].fillna(df.DepDelay.mean())
df['Distance'] = df['Distance'].fillna(0)

# %%
adult(df)
# Out:
#                      dtype  nulls  nulls_%  nunique sample
# Year                 int64      0      0.0        1   1987
# Month                int64      0      0.0        3     10
# DayofMonth           int64      0      0.0       31     14
# DayOfWeek            int64      0      0.0        7      3
# DepTime            float64      0      0.0     1431  741.0
# CRSDepTime           int64      0      0.0     1174    730
# ArrTime            float64      0      0.0     1441  912.0
# CRSArrTime           int64      0      0.0     1301    849
# UniqueCarrier          str      0      0.0       14     PS
# FlightNum            int64      0      0.0     2161   1451
# ActualElapsedTime  float64      0      0.0      648   91.0
# CRSElapsedTime       int64      0      0.0      431     79
# ArrDelay           float64      0      0.0      673   23.0
# DepDelay           float64      0      0.0      606   11.0
# Origin                 str      0      0.0      237    SAN
# Dest                   str      0      0.0      237    SFO
# Distance           float64      0      0.0     1026  447.0
# Cancelled            int64      0      0.0        2      0
# Diverted             int64      0      0.0        2      0

# %%
df.duplicated().sum()
# Out:
# np.int64(72)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('df_1987.csv', index=False, compression='gzip')

# %%
pd.read_csv('df_1987.csv', engine='pyarrow', compression='gzip')
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        1987     10          14          3    741.0         730    912.0
# 1        1987     10          15          4    729.0         730    903.0
# 2        1987     10          17          6    741.0         730    918.0
# 3        1987     10          18          7    729.0         730    847.0
# 4        1987     10          19          1    749.0         730    922.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1311749  1987     12          11          5   1530.0        1530   1825.0
# 1311750  1987     12          13          7   1530.0        1530   1815.0
# 1311751  1987     12          14          1   1530.0        1530   1807.0
# 1311752  1987     12           1          2   1525.0        1525   1643.0
# 1311753  1987     12           2          3   1540.0        1525   1706.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  \
# 0               849            PS       1451               91.0
# 1               849            PS       1451               94.0
# 2               849            PS       1451               97.0
# 3               849            PS       1451               78.0
# 4               849            PS       1451               93.0
# ...             ...           ...        ...                ...
# 1311749        1823            CO        638              115.0
# 1311750        1823            CO        638              105.0
# 1311751        1823            CO        638               97.0
# 1311752        1638            CO        639               78.0
# 1311753        1638            CO        639               86.0
#
#          CRSElapsedTime  ArrDelay  DepDelay Origin Dest  Distance  Cancelled  \
# 0                    79      23.0      11.0    SAN  SFO     447.0          0
# 1                    79      14.0      -1.0    SAN  SFO     447.0          0
# 2                    79      29.0      11.0    SAN  SFO     447.0          0
# 3                    79      -2.0      -1.0    SAN  SFO     447.0          0
# 4                    79      33.0      19.0    SAN  SFO     447.0          0
# ...                 ...       ...       ...    ...  ...       ...        ...
# 1311749             113       2.0       0.0    ORD  EWR     719.0          0
# 1311750             113      -8.0       0.0    ORD  EWR     719.0          0
# 1311751             113     -16.0       0.0    ORD  EWR     719.0          0
# 1311752              73       5.0       0.0    BOS  EWR     200.0          0
# 1311753              73      28.0      15.0    BOS  EWR     200.0          0
#
#          Diverted
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1311749         0
# 1311750         0
# 1311751         0
# 1311752         0
# 1311753         0
#
# [1311754 rows x 19 columns]
